# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('trialeval.csv') #place data in root folder or change path

# %%
#data = data.rename(columns={'Q6.1':'Q7'})
#data = data.drop('Unnamed: 0', axis=1)

# %%
#data.to_csv('trialeval.csv', index=False)

# %%
data
# Out:
#                                               Q1  ...                                                Q10
# 0   The chatbot was good at guessing my emotion.  ...   Please provide any additional comments you have.
# 1                                       Disagree  ...  Sorry that my comments seems discouraging. I t...
# 2                                 Strongly agree  ...                                                NaN
# 3                     Neither agree nor disagree  ...  * Overall, this was a huge step in the right d...
# 4                                          Agree  ...                                                NaN
# 5                                          Agree  ...                                                NaN
# 6                     Neither agree nor disagree  ...                                                NaN
# 7                                          Agree  ...  The responses feel quite general. This in turn...
# ...

# %%
#guessing emotion eval:
s_disag=0
disag=0
neither=0
agree=0
s_agree=0

for i, row in data.iterrows():
  if row['Q1'] == 'Strongly agree':
    s_agree += 1
  elif row['Q1'] == 'Agree':
    agree += 1
  elif row['Q1'] == 'Neither agree nor disagree':
    neither += 1
  elif row['Q1'] == 'Disagree':
    disag += 1
  elif row['Q1'] == 'Strongly disagree':
    s_disag += 1

guess_emo = [s_disag, disag, neither, agree, s_agree]

print(guess_emo)

norm_guess_emo = [i/sum(guess_emo) for i in guess_emo]

print(norm_guess_emo)
# Out:
# [0, 2, 4, 7, 3]
# [0.0, 0.125, 0.25, 0.4375, 0.1875]

# %%
#Kai empathy:

s_disag=0
disag=0
neither=0
agree=0
s_agree=0

for i, row in data.iterrows():
  if row['Q2'] == 'Strongly agree':
    s_agree += 1
  elif row['Q2'] == 'Agree':
    agree += 1
  elif row['Q2'] == 'Neither agree nor disagree':
    neither += 1
  elif row['Q2'] == 'Disagree':
    disag += 1
  elif row['Q2'] == 'Strongly disagree':
    s_disag += 1

kai_emp = [s_disag, disag, neither, agree, s_agree]

print(kai_emp)

norm_kai_emp = [i/sum(kai_emp) for i in kai_emp]

print(norm_kai_emp)
# Out:
# [0, 0, 2, 12, 2]
# [0.0, 0.0, 0.125, 0.75, 0.125]

# %%
#Kai engagement:

s_disag=0
disag=0
neither=0
agree=0
s_agree=0

for i, row in data.iterrows():
  if row['Q3'] == 'Strongly agree':
    s_agree += 1
  elif row['Q3'] == 'Agree':
    agree += 1
  elif row['Q3'] == 'Neither agree nor disagree':
    neither += 1
  elif row['Q3'] == 'Disagree':
    disag += 1
  elif row['Q3'] == 'Strongly disagree':
    s_disag += 1

kai_engag = [s_disag, disag, neither, agree, s_agree]

print(kai_engag)

norm_kai_engag = [i/sum(kai_engag) for i in kai_engag]

print(norm_kai_engag)
# Out:
# [0, 1, 4, 10, 1]
# [0.0, 0.0625, 0.25, 0.625, 0.0625]

# %%
#Others empathy:

s_disag=0
disag=0
neither=0
agree=0
s_agree=0

for i, row in data.iterrows():
  if row['Q5'] == 'Strongly agree':
    s_agree += 1
  elif row['Q5'] == 'Agree':
    agree += 1
  elif row['Q5'] == 'Neither agree nor disagree':
    neither += 1
  elif row['Q5'] == 'Disagree':
    disag += 1
  elif row['Q5'] == 'Strongly disagree':
    s_disag += 1

others_emp = [s_disag, disag, neither, agree, s_agree]

print(others_emp)

norm_others_emp = [i/sum(others_emp) for i in others_emp]

print(norm_others_emp)
# Out:
# [0, 0, 4, 9, 3]
# [0.0, 0.0, 0.25, 0.5625, 0.1875]

# %%
#Others engagement:

s_disag=0
disag=0
neither=0
agree=0
s_agree=0

for i, row in data.iterrows():
  if row['Q6'] == 'Strongly agree':
    s_agree += 1
  elif row['Q6'] == 'Agree':
    agree += 1
  elif row['Q6'] == 'Neither agree nor disagree':
    neither += 1
  elif row['Q6'] == 'Disagree':
    disag += 1
  elif row['Q6'] == 'Strongly disagree':
    s_disag += 1

others_engag = [s_disag, disag, neither, agree, s_agree]

print(others_engag)

norm_others_engag = [i/sum(others_engag) for i in others_engag]

print(norm_others_engag)
# Out:
# [0, 1, 4, 9, 2]
# [0.0, 0.0625, 0.25, 0.5625, 0.125]

# %%
#Usefulness:

s_disag=0
disag=0
neither=0
agree=0
s_agree=0

for i, row in data.iterrows():
  if row['Q6.1'] == 'Strongly agree':
    s_agree += 1
  elif row['Q6.1'] == 'Agree':
    agree += 1
  elif row['Q6.1'] == 'Neither agree nor disagree':
    neither += 1
  elif row['Q6.1'] == 'Disagree':
    disag += 1
  elif row['Q6.1'] == 'Strongly disagree':
    s_disag += 1

use = [s_disag, disag, neither, agree, s_agree]

print(use)

norm_use = [i/sum(use) for i in use]

print(norm_use)
# Out:
# [0, 0, 1, 9, 2]
# [0.0, 0.0, 0.08333333333333333, 0.75, 0.16666666666666666]

# %%
#personas chosen (apart from kai)

robert=0
gabrielle=0
arman=0
olivia=0


for i, row in data.iterrows():
  if 'Robert' in row['Q4']:
    robert += 1
  if 'Gabrielle' in row['Q4']:
    gabrielle += 1
  if 'Arman' in row['Q4']:
    arman += 1
  if 'Olivia' in row['Q4']:
    olivia += 1
personas = [robert, gabrielle, arman, olivia]

print(personas)

norm_personas = [i/sum(personas) for i in personas]

print(norm_personas)
# Out:
# [8, 4, 8, 7]
# [0.2962962962962963, 0.14814814814814814, 0.2962962962962963, 0.25925925925925924]

# %% [markdown]
# ###Evaluation results of previous version for comparison

# %%
prev_emp = [1,4,3,2,0]
prev_use = [0,1,5,2,2]
prev_engag = [0,4,3,1,2]

# %%
norm_prev_emp = [i/sum(prev_emp) for i in prev_emp]
norm_prev_use = [i/sum(prev_use) for i in prev_use]
norm_prev_engag = [i/sum(prev_engag) for i in prev_engag]

# %%
print(norm_prev_emp)
print(norm_prev_use)
print(norm_prev_engag)
# Out:
# [0.1, 0.4, 0.3, 0.2, 0.0]
# [0.0, 0.1, 0.5, 0.2, 0.2]
# [0.0, 0.4, 0.3, 0.1, 0.2]

# %% [markdown]
# ###Comparison

# %% [markdown]
# guess emotion:

# %%
labels = ['Strongly disagree', 'Disagree', 'Neither agree nor disagree', 'Agree', 'Strongly Agree']
guess_emo_df = pd.DataFrame(list(zip(labels, norm_guess_emo)),
               columns =['response', 'percentage'])

# %%
guess_emo_df
# Out:
#                      response  percentage
# 0           Strongly disagree      0.0000
# 1                    Disagree      0.1250
# 2  Neither agree nor disagree      0.2500
# 3                       Agree      0.4375
# 4              Strongly Agree      0.1875

# %%
#guess emotion
plt.rcParams.update({'font.size': 20})
ax = guess_emo_df.plot.bar(figsize=(15,8), title="'The chatbot was good at guessing my emotion'", 
                                             fontsize=20, rot=0, color='mediumblue', ylim=(0,0.50));

ticks = ['Strongly \n disagree', 'Disagree', 'Neither agree \n nor disagree', 'Agree', 'Strongly \n Agree']
ax.set_xticklabels(ticks, fontsize=20);
ax.set_yticklabels(['0%', '10%', '20%', '30%', '40%', '50%']);
plt.legend(loc='upper left', prop={"size":20});

# %% [markdown]
# empathy:

# %%
kai_emp_df = pd.DataFrame(list(zip(labels, norm_kai_emp)),
               columns =['response', 'percentage'])

others_emp_df = pd.DataFrame(list(zip(labels, norm_others_emp)),
               columns =['response', 'percentage'])

prev_emp_df = pd.DataFrame(list(zip(labels, norm_prev_emp)),
               columns =['response', 'percentage'])

# %%
ticks = ['Strongly \n disagree', 'Disagree', 'Neither agree \n nor disagree', 'Agree', 'Strongly \n Agree']

plt.rcParams.update({'font.size': 32})
fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(25,8));
fig.suptitle("'The chatbot displayed empathy in its responses throughout the conversation'")
plt.setp(axes,  ylim=(0,0.8), xticklabels=ticks, yticklabels=['0%', '10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%'])
plt.rcParams.update({'font.size': 18})
prev_emp_df.plot.bar(ax=axes[0], color='orangered', title='Previous version');
axes[0].legend(loc='upper left', fontsize=26);
axes[0].set_xticklabels(ticks, fontsize=20, rotation=50);
kai_emp_df.plot.bar(ax=axes[1], color='mediumblue', title='Current version: Kai');
axes[1].legend(loc='upper left', fontsize=26);
axes[1].set_xticklabels(ticks, fontsize=20, rotation=50);
others_emp_df.plot.bar(ax=axes[2], color='mediumblue', title='Current version: other personas');
axes[2].legend(loc='upper left', fontsize=26);
axes[2].set_xticklabels(ticks, fontsize=20, rotation=50);

# %% [markdown]
# engagement:

# %%
kai_engag_df = pd.DataFrame(list(zip(labels, norm_kai_engag)),
               columns =['response', 'percentage'])

others_engag_df = pd.DataFrame(list(zip(labels, norm_others_engag)),
               columns =['response', 'percentage'])

prev_engag_df = pd.DataFrame(list(zip(labels, norm_prev_engag)),
               columns =['response', 'percentage'])

# %%
plt.rcParams.update({'font.size': 32})
fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(25,8));
fig.suptitle("'I found the conversation with the chatbot to be engaging'")
plt.setp(axes,  ylim=(0,0.8), xticklabels=ticks, yticklabels=['0%', '10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%'])
plt.rcParams.update({'font.size': 20})
prev_engag_df.plot.bar(ax=axes[0], color='orangered', title='Previous version');
axes[0].legend(loc='upper left', fontsize=26);
axes[0].set_xticklabels(ticks, fontsize=20, rotation=50);
kai_engag_df.plot.bar(ax=axes[1], color='mediumblue', title='Current version: Kai');
axes[1].legend(loc='upper left', fontsize=26);
axes[1].set_xticklabels(ticks, fontsize=20, rotation=50);
others_engag_df.plot.bar(ax=axes[2], color='mediumblue', title='Current version: other personas');
axes[2].legend(loc='upper left', fontsize=26);
axes[2].set_xticklabels(ticks, fontsize=20, rotation=50);

# %% [markdown]
# usefulness:

# %%
use_df = pd.DataFrame(list(zip(labels, norm_use)),
               columns =['response', 'percentage'])

prev_use_df = pd.DataFrame(list(zip(labels, norm_prev_use)),
               columns =['response', 'percentage'])

# %%
plt.rcParams.update({'font.size': 32})
fig, axes = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(18,8));
fig.suptitle("'Overall, the platform was useful'")
plt.setp(axes,  ylim=(0,0.8), xticklabels=ticks, yticklabels=['0%', '10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%'])
plt.rcParams.update({'font.size': 20})
prev_use_df.plot.bar(ax=axes[0], color='orangered', title='Previous version');
axes[0].legend(loc='upper left', fontsize=26);
axes[0].set_xticklabels(ticks, fontsize=20, rotation=50);
use_df.plot.bar(ax=axes[1], color='mediumblue', title='Current version');
axes[1].legend(loc='upper left', fontsize=26);
axes[1].set_xticklabels(ticks, fontsize=20, rotation=50);

# %% [markdown]
# choice of personas:

# %%
personas_df = pd.DataFrame(list(zip(labels, norm_personas)),
               columns =['persona', 'percentage'])

# %%
plt.rcParams.update({'font.size': 18})
ax = personas_df.plot.bar(figsize=(15,8), title="Chosen personas (other than Kai)", 
                                             fontsize=18, rot=0, color='mediumblue', ylim=(0,0.5));

ax.set_xticklabels(['Robert', 'Gabrielle', 'Arman', 'Olivia']);
ax.set_yticklabels(['0%', '10%', '20%', '30%', '40%', '50%']);
plt.legend(loc='upper left');
